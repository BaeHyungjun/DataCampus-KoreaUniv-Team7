# %%
from requests import request
from requests.compat import urljoin, urlparse
from requests.exceptions import HTTPError
from urllib.robotparser import RobotFileParser
from bs4 import BeautifulSoup
import time
import re
import random

def canfetch(url, agent='*', path='/'):
    robot = RobotFileParser(urljoin(url, '/robots.txt'))
    robot.read()
    return robot.can_fetch(agent, urlparse(url)[2])
    
def download(url, params={}, headers={}, method='GET', limit=3):
    try:
        resp = request(method, url,
               params=params if method=='GET' else {},
               data=params if method=='POST' else {},
               headers=headers)
        resp.raise_for_status()
    except HTTPError as e:
        if limit > 0 and e.response.status_code >= 500:
            print(limit, resp.request.url)
            time.sleep(random.random()*5) # => random
            resp = download(url, params, headers, method, limit-1)
        else:
            print('[{}] '.format(e.response.status_code) + url)
            print(e.response.status_code)
            print(e.response.reason)
            print(e.response.headers)
    return resp

# %% [markdown]
# ### 네이버뉴스 수집 - 200701부터 6개분야에서 top30

# %%
import pandas as pd
pd.to_datetime('20200801', format='%Y%m%d')
# Out:
# Timestamp('2020-08-01 00:00:00')

# %%
from datetime import datetime, timedelta 

start_date = datetime.strptime('20180731', '%Y%m%d') 
end_date = datetime.today()
str_date_list = [] 
while start_date.strftime('%Y%m%d') != end_date.strftime('%Y%m%d'): 
    str_date_list.append(start_date.strftime('%Y%m%d')) 
    start_date += timedelta(days=1)

# %%
str_date_list[:3], str_date_list[-3:] #날짜확인
# Out:
# (['20180731', '20180801', '20180802'], ['20200805', '20200806', '20200807'])

# %% [markdown]
# ### 링크수집

# %%
urlst = []
for i in range(6):
    for j in str_date_list[:2]: #just for test
        url = 'https://news.naver.com/main/ranking/popularDay.nhn'

        params = {
            'rankingType': 'popular_day',
        }

        params['sectionId'] = '10'+str(i)
        params['date']=j

        headers = {
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'
        }

        resp = download(url, params=params, headers=headers)
        dom = BeautifulSoup(resp.content, 'lxml')


        #뉴스링크 수집
        for _ in dom.find_all('a',{'class':'nclicks(rnk.eco)'}):
            if _['href'] not in urlst:
                urlst.append(_['href'])

# %%
urlst[:3] #url확인
# Out:
# ['/main/ranking/read.nhn?rankingType=popular_day&oid=001&aid=0010244310&date=20180731&type=1&rankingSectionId=101&rankingSeq=1',
#  '/main/ranking/read.nhn?rankingType=popular_day&oid=028&aid=0002419466&date=20180731&type=1&rankingSectionId=101&rankingSeq=2',
#  '/main/ranking/read.nhn?rankingType=popular_day&oid=015&aid=0003988450&date=20180731&type=1&rankingSectionId=101&rankingSeq=4']

# %%
#get html from article address
for _ in urlst:
    newslink = urljoin(url, _)
    resp = download(newslink, headers=headers)
    if resp.status_code!=200:
        continue
    dom = BeautifulSoup(resp.content, 'html.parser')
    break

# %% [markdown]
# ### 제목스크래핑

# %%
dom.find('h3', {'id':'articleTitle'}).text.strip()
# Out:
# '리콜 대상 BMW 420d 주행 중 또 화재…이번엔 경인고속도로'

# %% [markdown]
# ### 기사작성일

# %%
dom.find_all('span', {'class':'t11'})[0].text.strip()
# Out:
# '2018.07.31. 오후 5:57'

# %% [markdown]
# ### 본문스크래핑

# %%
dom.find_all('div',{'id':'articleBodyContents'})[0].text.strip()
# Out:
# '// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}\n\n경인고속도로 달리던 리콜대상 BMW 차량서 불(인천=연합뉴스) 31일 오후 4시 26분께 인천시 서구 경인고속도로 서울 방향 가좌IC 인근에서 주행 중인 BMW 420d 차량에 불이 붙어 소방당국이 진화했다. 불이 난 차량은 최근 BMW코리아가 조치한 리콜대상에 포함된 차종이다.2018.7.31   [인천 서부소방서 제공]BMW 10만6,000여대 리콜…27일부터 안전진단(CG)[연합뉴스TV 제공](인천=연합뉴스) 최은지 기자 = 최근 잇따른 주행 중 화재 사고로 리콜(시정명령) 결정이 내려진 BMW 차량에서 운행 중 또 불이 났다.    31일 인천 서부소방서에 따르면 이날 오후 4시 26분께 인천시 서구 경인고속도로 서울 방향 가좌IC 인근에서 주행 중인 420d 차량에 불이 붙었다.    이 차량 운전자는 소방당국에 "엔진룸에서 불이 났다"고 진술했다.    화재 당시 운전자 등 2명이 차량에 타고 있었으나 모두 신속히 대피해 인명피해는 없었다.    불이 난 차량은 2014년식 BMW 420d로, 최근 BMW코리아가 조치한 리콜대상에 포함된 차종이다.    소방당국은 신고를 받고 출동해 9분 만인 이날 오후 4시 35분께 불을 모두 껐다.    BMW코리아는 이달 26일 BMW 520d 등 총 42개 차종 10만6천317대를 대상으로 자발적 리콜조치를 한다고 밝혔다.    BMW는 27일부터 해당 차량 전체에 대해 긴급 안전진단을 벌이고 있으며 8월 중순부터 엔진에 장착된 배기가스 재순환장치(EGR) 모듈 개선품 교체를 본격 진행할 예정이다.    BMW 측의 자발적인 리콜 조치가 내려진 상황에서도 차량 화재가 잇따르자 BMW 운전자들은 불안을 호소했다.    전날 낮 12시께 인천시 서구 수도권 제2외곽순환고속도로 인천∼김포 구간(인천김포고속도로) 내 북항터널에서도 달리던 BMW GT 차량에 불이 붙었다. 당일 불이 난 2013년식 BMW GT도 리콜대상에 포함된 차종이었다.    chamse@yna.co.kr ▶놓치면 아쉬운 \'핫뉴스\'  ▶퀴즈풀고 상품받고! 뉴스퀴즈쇼 \'뉴나\'▶네이버 홈에서 [연합뉴스] 채널 구독하기'

# %%
txt = dom.find_all('div',{'id':'articleBodyContents'})[0].text.replace(
            '\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}\n\n','').replace(
            '<br/>','').strip()

txt = txt[:re.search("▶", txt).start()]
txt
# Out:
# '경인고속도로 달리던 리콜대상 BMW 차량서 불(인천=연합뉴스) 31일 오후 4시 26분께 인천시 서구 경인고속도로 서울 방향 가좌IC 인근에서 주행 중인 BMW 420d 차량에 불이 붙어 소방당국이 진화했다. 불이 난 차량은 최근 BMW코리아가 조치한 리콜대상에 포함된 차종이다.2018.7.31   [인천 서부소방서 제공]BMW 10만6,000여대 리콜…27일부터 안전진단(CG)[연합뉴스TV 제공](인천=연합뉴스) 최은지 기자 = 최근 잇따른 주행 중 화재 사고로 리콜(시정명령) 결정이 내려진 BMW 차량에서 운행 중 또 불이 났다.    31일 인천 서부소방서에 따르면 이날 오후 4시 26분께 인천시 서구 경인고속도로 서울 방향 가좌IC 인근에서 주행 중인 420d 차량에 불이 붙었다.    이 차량 운전자는 소방당국에 "엔진룸에서 불이 났다"고 진술했다.    화재 당시 운전자 등 2명이 차량에 타고 있었으나 모두 신속히 대피해 인명피해는 없었다.    불이 난 차량은 2014년식 BMW 420d로, 최근 BMW코리아가 조치한 리콜대상에 포함된 차종이다.    소방당국은 신고를 받고 출동해 9분 만인 이날 오후 4시 35분께 불을 모두 껐다.    BMW코리아는 이달 26일 BMW 520d 등 총 42개 차종 10만6천317대를 대상으로 자발적 리콜조치를 한다고 밝혔다.    BMW는 27일부터 해당 차량 전체에 대해 긴급 안전진단을 벌이고 있으며 8월 중순부터 엔진에 장착된 배기가스 재순환장치(EGR) 모듈 개선품 교체를 본격 진행할 예정이다.    BMW 측의 자발적인 리콜 조치가 내려진 상황에서도 차량 화재가 잇따르자 BMW 운전자들은 불안을 호소했다.    전날 낮 12시께 인천시 서구 수도권 제2외곽순환고속도로 인천∼김포 구간(인천김포고속도로) 내 북항터널에서도 달리던 BMW GT 차량에 불이 붙었다. 당일 불이 난 2013년식 BMW GT도 리콜대상에 포함된 차종이었다.    chamse@yna.co.kr '

# %% [markdown]
# ### 요약본 스크래핑

# %%
newslink =  urljoin(url, urlst[0]) #for test
parsed = (urlparse(newslink)).query.split('&')
oid = parsed[1]
aid = parsed[2]
print(oid, aid)

oidno = re.search(re.compile(r'[^oid=]{3}'), oid).group(0)
print(oidno)

aidno = re.search(re.compile(r'[^aid=]{10}'), aid).group(0)
print(aidno)
# Out:
# oid=001 aid=0010244310
# 001
# 0010244310

# %%
sumurl = 'https://tts.news.naver.com/article/'+oidno+'/'+aidno+'/summary'
sumresp = download(sumurl)
json = sumresp.json()
json['summary']
# Out:
# '최근 잇따른 주행 중 화재 사고로 리콜 결정이 내려진 BMW 차량에서 운행 중 또 불이 났다.<br/><br/>전날 낮 12시께 인천시 서구 수도권 제2외곽순환고속도로 인천∼김포 구간 내 북항터널에서도 달리던 BMW GT 차량에 불이 붙었다.<br/><br/>당일 불이 난 2013년식 BMW GT도 리콜대상에 포함된 차종이었다.'

# %%
summary = json['summary'].replace('<br/>','')
summary
# Out:
# '최근 잇따른 주행 중 화재 사고로 리콜 결정이 내려진 BMW 차량에서 운행 중 또 불이 났다.전날 낮 12시께 인천시 서구 수도권 제2외곽순환고속도로 인천∼김포 구간 내 북항터널에서도 달리던 BMW GT 차량에 불이 붙었다.당일 불이 난 2013년식 BMW GT도 리콜대상에 포함된 차종이었다.'

# %% [markdown]
# ### combined

# %%
for _ in urlst:
    newslink = urljoin(url, _)
    resp = download(newslink, headers=headers)
    if resp.status_code!=200:
        continue
    dom = BeautifulSoup(resp.content, 'html.parser')
    if dom.find_all('a',{'class':'media_end_head_autosummary_button _toggle_btn nclicks(sum_summary)'}) != []:
        #제목
        title = dom.find('h3', {'id':'articleTitle'}).text.strip()
        #기사작성일
        date = dom.find_all('span', {'class':'t11'})[0].text.strip()
        #본문
        body = dom.find_all('div',{'id':'articleBodyContents'})[0].text.replace(
            '\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}\n\n','').replace(
            '<br/>','').strip()
        
        if re.search("▶", body):
            body = body[:re.search("▶", body).start()]

        parsed = (urlparse(newslink)).query.split('&')
        oid = parsed[1]
        aid = parsed[2]

        oidno = re.search(re.compile(r'[^oid=]{3}'), oid).group(0)
        aidno = re.search(re.compile(r'[^aid=]{10}'), aid).group(0)

        sumurl = 'https://tts.news.naver.com/article/'+oidno+'/'+aidno+'/summary'
        sumresp = download(sumurl)
        if sumresp.status_code!=200:
            continue
        json = sumresp.json()
        #요약
        summary = json['summary'].replace('<br/>','')

        print(title)
        print(date)
        print(body)
        print(summary)
        break
# Out:
# 리콜 대상 BMW 420d 주행 중 또 화재…이번엔 경인고속도로
# 2018.07.31. 오후 5:57
# 경인고속도로 달리던 리콜대상 BMW 차량서 불(인천=연합뉴스) 31일 오후 4시 26분께 인천시 서구 경인고속도로 서울 방향 가좌IC 인근에서 주행 중인 BMW 420d 차량에 불이 붙어 소방당국이 진화했다. 불이 난 차량은 최근 BMW코리아가 조치한 리콜대상에 포함된 차종이다.2018.7.31   [인천 서부소방서 제공]BMW 10만6,000여대 리콜…27일부터 안전진단(CG)[연합뉴스TV 제공](인천=연합뉴스) 최은지 기자 = 최근 잇따른 주행 중 화재 사고로 리콜(시정명령) 결정이 내려진 BMW 차량에서 운행 중 또 불이 났다.    31일 인천 서부소방서에 따르면 이날 오후 4시 26분께 인천시 서구 경인고속도로 서울 방향 가좌IC 인근에서 주행 중인 420d 차량에 불이 붙었다.    이 차량 운전자는 소방당국에 "엔진룸에서 불이 났다"고 진술했다.    화재 당시 운전자 등 2명이 차량에 타고 있었으나 모두 신속히 대피해 인명피해는 없었다.    불이 난 차량은 2014년식 BMW 420d로, 최근 BMW코리아가 조치한 리콜대상에 포함된 차종이다.    소방당국은 신고를 받고 출동해 9분 만인 이날 오후 4시 35분께 불을 모두 껐다.    BMW코리아는 이달 26일 BMW 520d 등 총 42개 차종 10만6천317대를 대상으로 자발적 리콜조치를 한다고 밝혔다.    BMW는 27일부터 해당 차량 전체에 대해 긴급 안전진단을 벌이고 있으며 8월 중순부터 엔진에 장착된 배기가스 재순환장치(EGR) 모듈 개선품 교체를 본격 진행할 예정이다.    BMW 측의 자발적인 리콜 조치가 내려진 상황에서도 차량 화재가 잇따르자 BMW 운전자들은 불안을 호소했다.    전날 낮 12시께 인천시 서구 수도권 제2외곽순환고속도로 인천∼김포 구간(인천김포고속도로) 내 북항터널에서도 달리던 BMW GT 차량에 불이 붙었다. 당일 불이 난 2013년식 BMW GT도 리콜대상에 포함된 차종이었다.    chamse@yna.co.kr
# 최근 잇따른 주행 중 화재 사고로 리콜 결정이 내려진 BMW 차량에서 운행 중 또 불이 났다.전날 낮 12시께 인천시 서구 수도권 제2외곽순환고속도로 인천∼김포 구간 내 북항터널에서도 달리던 BMW GT 차량에 불이 붙었다.당일 불이 난 2013년식 BMW GT도 리콜대상에 포함된 차종이었다.

# %% [markdown]
# ### DB에 넣기

# %%
import sqlite3

conn = sqlite3.connect('news.db')
cur = conn.cursor()

# %%
cur.executescript('''
    DROP TABLE IF EXISTS navernews;
    CREATE TABLE navernews(
        id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL,
        title TEXT NOT NULL,
        date TEXT,
        body TEXT,
        summary TEXT,
        link TEXT NOT NULL
    );
''')

# %%
for j in str_date_list:
    for i in range(6):
        print(j,i)
        url = 'https://news.naver.com/main/ranking/popularDay.nhn'

        params = {
            'rankingType': 'popular_day',
        }

        params['sectionId'] = '10'+str(i)
        params['date']=j

        headers = {
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'
        }

        resp = download(url, params=params, headers=headers)
        if resp.status_code!=200:
            continue
        dom = BeautifulSoup(resp.content, 'lxml')
        
        
        #뉴스링크 수집
        urlst = []
        for _ in dom.find_all('div',{'class':'ranking_headline'}):
            if _.a['href'] not in urlst:
                urlst.append(_.a['href'])
        
        for _ in urlst:
            newslink = urljoin(url, _)
            resp = download(newslink, headers=headers)
            if resp.status_code!=200:
                continue
            dom = BeautifulSoup(resp.content, 'html.parser')
            if dom.find_all('a',{'class':'media_end_head_autosummary_button _toggle_btn nclicks(sum_summary)'}) != []:
                #제목
                title = dom.find('h3', {'id':'articleTitle'}).text.strip()
                #기사작성일
                date = dom.find_all('span', {'class':'t11'})[0].text.strip()
                #본문
                body = dom.find_all('div',{'id':'articleBodyContents'})[0].text.replace(
                    '\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}\n\n','').replace(
                    '<br/>','').strip()

                if re.search("▶", body):
                    body = body[:re.search("▶", body).start()]

                parsed = (urlparse(newslink)).query.split('&')
                oid = parsed[1]
                aid = parsed[2]

                oidno = re.search(re.compile(r'[^oid=]{3}'), oid).group(0)
                aidno = re.search(re.compile(r'[^aid=]{10}'), aid).group(0)

                sumurl = 'https://tts.news.naver.com/article/'+oidno+'/'+aidno+'/summary'
                sumresp = download(sumurl)
                if sumresp.status_code!=200:
                    continue
                json = sumresp.json()
                #요약
                summary = json['summary'].replace('<br/>','')

                cur.execute('INSERT INTO navernews VALUES(NULL,?,?,?,?,?)',[title,date,body,summary,newslink])
                conn.commit()
# Out:
# 20180731 0
# 20180731 1
# 20180731 2
# 20180731 3
# 20180731 4
# 20180731 5
# 20180801 0
# 20180801 1
# 20180801 2
# 20180801 3
# 20180801 4
# 20180801 5
# 20180802 0
# 20180802 1
# 20180802 2
# 20180802 3
# 20180802 4
# 20180802 5
# 20180803 0
# 20180803 1
# 20180803 2
# 20180803 3
# 20180803 4
# 20180803 5
# 20180804 0
# 20180804 1
# 20180804 2
# 20180804 3
# 20180804 4
# 20180804 5
# 20180805 0
# 20180805 1
# 20180805 2
# 20180805 3
# 20180805 4
# 20180805 5
# 20180806 0
# 20180806 1
# 20180806 2
# 20180806 3
# 20180806 4
# 20180806 5
# 20180807 0
# 20180807 1
# 20180807 2
# 20180807 3
# 20180807 4
# 20180807 5
# 20180808 0
# 20180808 1
# 20180808 2
# 20180808 3
# 20180808 4
# 20180808 5
# 20180809 0
# 20180809 1
# 20180809 2
# 20180809 3
# 20180809 4
# 20180809 5
# 20180810 0
# 20180810 1
# 20180810 2
# 20180810 3
# 20180810 4
# 20180810 5
# 20180811 0
# 20180811 1
# 20180811 2
# 20180811 3
# 20180811 4
# 20180811 5
# 20180812 0
# 20180812 1
# 20180812 2
# 20180812 3
# 20180812 4
# 20180812 5
# 20180813 0
# 20180813 1
# 20180813 2
# 20180813 3
# 20180813 4
# 20180813 5
# 20180814 0
# 20180814 1
# 20180814 2
# 20180814 3
# 20180814 4
# 20180814 5
# 20180815 0
# 20180815 1
# 20180815 2
# 20180815 3
# 20180815 4
# 20180815 5
# 20180816 0
# 20180816 1
# 20180816 2
# 20180816 3
# 20180816 4
# 20180816 5
# 20180817 0
# 20180817 1
# 20180817 2
# 20180817 3
# 20180817 4
# 20180817 5
# 20180818 0
# 20180818 1
# 20180818 2
# 20180818 3
# 20180818 4
# 20180818 5
# 20180819 0
# 20180819 1
# 20180819 2
# 20180819 3
# 20180819 4
# 20180819 5
# 20180820 0
# 20180820 1
# 20180820 2
# 20180820 3
# 20180820 4
# 20180820 5
# 20180821 0
# 20180821 1
# 20180821 2
# 20180821 3
# 20180821 4
# 20180821 5
# 20180822 0
# 20180822 1
# 20180822 2
# 20180822 3
# 20180822 4
# 20180822 5
# 20180823 0
# 20180823 1
# 20180823 2
# 20180823 3
# 20180823 4
# 20180823 5
# 20180824 0
# 20180824 1
# 20180824 2
# 20180824 3
# 20180824 4
# 20180824 5
# 20180825 0
# 20180825 1
# 20180825 2
# 20180825 3
# 20180825 4
# 20180825 5
# 20180826 0
# 20180826 1
# 20180826 2
# 20180826 3
# 20180826 4
# 20180826 5
# 20180827 0
# 20180827 1
# 20180827 2
# 20180827 3
# 20180827 4
# 20180827 5
# 20180828 0
# 20180828 1
# 20180828 2
# 20180828 3
# 20180828 4
# 20180828 5
# 20180829 0
# 20180829 1
# 20180829 2
# 20180829 3
# 20180829 4
# 20180829 5
# 20180830 0
# 20180830 1
# 20180830 2
# 20180830 3
# 20180830 4
# 20180830 5
# 20180831 0
# 20180831 1
# 20180831 2
# 20180831 3
# 20180831 4
# 20180831 5
# 20180901 0
# 20180901 1
# 20180901 2
# 20180901 3
# 20180901 4
# 20180901 5
# 20180902 0
# 20180902 1
# 20180902 2
# 20180902 3
# 20180902 4
# 20180902 5
# 20180903 0
# 20180903 1
# 20180903 2
# 20180903 3
# 20180903 4
# 20180903 5
# 20180904 0
# 20180904 1
# 20180904 2
# 20180904 3
# 20180904 4
# 20180904 5
# 20180905 0
# 20180905 1
# 20180905 2
# 20180905 3
# 20180905 4
# 20180905 5
# 20180906 0
# 20180906 1
# 20180906 2
# 20180906 3
# 20180906 4
# 20180906 5
# 20180907 0
# 20180907 1
# 20180907 2
# 20180907 3
# 20180907 4
# 20180907 5
# 20180908 0
# 20180908 1
# 20180908 2
# 20180908 3
# 20180908 4
# 20180908 5
# 20180909 0
# 20180909 1
# 20180909 2
# 20180909 3
# 20180909 4
# 20180909 5
# 20180910 0
# 20180910 1
# 20180910 2
# 20180910 3
# 20180910 4
# 20180910 5
# 20180911 0
# 20180911 1
# 20180911 2
# 20180911 3
# 20180911 4
# 20180911 5
# 20180912 0
# 20180912 1
# 20180912 2
# 20180912 3
# 20180912 4
# 20180912 5
# 20180913 0
# 20180913 1
# 20180913 2
# 20180913 3
# 20180913 4
# 20180913 5
# 20180914 0
# 20180914 1
# 20180914 2
# 20180914 3
# 20180914 4
# 20180914 5
# 20180915 0
# 20180915 1
# 20180915 2
# 20180915 3
# 20180915 4
# 20180915 5
# 20180916 0
# 20180916 1
# 20180916 2
# 20180916 3
# 20180916 4
# 20180916 5
# 20180917 0
# 20180917 1
# 20180917 2
# 20180917 3
# 20180917 4
# 20180917 5
# 20180918 0
# 20180918 1
# 20180918 2
# 20180918 3
# 20180918 4
# 20180918 5
# 20180919 0
# 20180919 1
# 20180919 2
# 20180919 3
# 20180919 4
# 20180919 5
# 20180920 0
# 20180920 1
# 20180920 2
# 20180920 3
# 20180920 4
# 20180920 5
# 20180921 0
# 20180921 1
# 20180921 2
# 20180921 3
# 20180921 4
# 20180921 5
# 20180922 0
# 20180922 1
# 20180922 2
# 20180922 3
# 20180922 4
# 20180922 5
# 20180923 0
# 20180923 1
# 20180923 2
# 20180923 3
# 20180923 4
# 20180923 5
# 20180924 0
# 20180924 1
# 20180924 2
# 20180924 3
# 20180924 4
# 20180924 5
# 20180925 0
# 20180925 1
# 20180925 2
# 20180925 3
# 20180925 4
# 20180925 5
# 20180926 0
# 20180926 1
# 20180926 2
# 20180926 3
# 20180926 4
# 20180926 5
# 20180927 0
# 20180927 1
# 20180927 2
# 20180927 3
# 20180927 4
# 20180927 5
# 20180928 0
# 20180928 1
# 20180928 2
# 20180928 3
# 20180928 4
# 20180928 5
# 20180929 0
# 20180929 1
# 20180929 2
# 20180929 3
# 20180929 4
# 20180929 5
# 20180930 0
# 20180930 1
# 20180930 2
# 20180930 3
# 20180930 4
# 20180930 5
# 20181001 0
# 20181001 1
# 20181001 2
# 20181001 3
# 20181001 4
# 20181001 5
# 20181002 0
# 20181002 1
# 20181002 2
# 20181002 3
# 20181002 4
# 20181002 5
# 20181003 0
# 20181003 1
# 20181003 2
# 20181003 3
# 20181003 4
# 20181003 5
# 20181004 0
# 20181004 1
# 20181004 2
# 20181004 3
# 20181004 4
# 20181004 5
# 20181005 0
# 20181005 1
# 20181005 2
# 20181005 3
# 20181005 4
# 20181005 5
# 20181006 0
# 20181006 1
# 20181006 2
# 20181006 3
# 20181006 4
# 20181006 5
# 20181007 0
# 20181007 1
# 20181007 2
# 20181007 3
# 20181007 4
# 20181007 5
# 20181008 0
# 20181008 1
# 20181008 2
# 20181008 3
# 20181008 4
# 20181008 5
# 20181009 0
# 20181009 1
# 20181009 2
# 20181009 3
# 20181009 4
# 20181009 5
# 20181010 0
# 20181010 1
# 20181010 2
# 20181010 3
# 20181010 4
# 20181010 5
# 20181011 0
# 20181011 1
# 20181011 2
# 20181011 3
# 20181011 4
# 20181011 5
# 20181012 0
# 20181012 1
# 20181012 2
# 20181012 3
# 20181012 4
# 20181012 5
# 20181013 0
# 20181013 1
# 20181013 2
# 20181013 3
# 20181013 4
# 20181013 5
# 20181014 0
# 20181014 1
# 20181014 2
# 20181014 3
# 20181014 4
# 20181014 5
# 20181015 0
# 20181015 1
# 20181015 2
# 20181015 3
# 20181015 4
# 20181015 5
# 20181016 0
# 20181016 1
# 20181016 2
# 20181016 3
# 20181016 4
# 20181016 5
# 20181017 0
# 20181017 1
# 20181017 2
# 20181017 3
# 20181017 4
# 20181017 5
# 20181018 0
# 20181018 1
# 20181018 2
# 20181018 3
# 20181018 4
# 20181018 5
# 20181019 0
# 20181019 1
# 20181019 2
# 20181019 3
# 20181019 4
# 20181019 5
# 20181020 0
# 20181020 1
# 20181020 2
# 20181020 3
# 20181020 4
# 20181020 5
# 20181021 0
# 20181021 1
# 20181021 2
# 20181021 3
# 20181021 4
# 20181021 5
# 20181022 0
# 20181022 1
# 20181022 2
# 20181022 3
# 20181022 4
# 20181022 5
# 20181023 0
# 20181023 1
# 20181023 2
# 20181023 3
# 20181023 4
# 20181023 5
# 20181024 0
# 20181024 1
# 20181024 2
# 20181024 3
# 20181024 4
# 20181024 5
# 20181025 0
# 20181025 1
# 20181025 2
# 20181025 3
# 20181025 4
# 20181025 5
# 20181026 0
# 20181026 1
# 20181026 2
# 20181026 3
# 20181026 4
# 20181026 5
# 20181027 0
# 20181027 1
# 20181027 2
# 20181027 3
# 20181027 4
# 20181027 5
# 20181028 0
# 20181028 1
# 20181028 2
# 20181028 3
# 20181028 4
# 20181028 5
# 20181029 0
# 20181029 1
# 20181029 2
# 20181029 3
# 20181029 4
# 20181029 5
# 20181030 0
# 20181030 1
# 20181030 2
# 20181030 3
# 20181030 4
# 20181030 5
# 20181031 0
# 20181031 1
# 20181031 2
# 20181031 3
# 20181031 4
# 20181031 5
# 20181101 0
# 20181101 1
# 20181101 2
# 20181101 3
# 20181101 4
# 20181101 5
# 20181102 0
# 20181102 1
# 20181102 2
# 20181102 3
# 20181102 4
# 20181102 5
# 20181103 0
# 20181103 1
# 20181103 2
# 20181103 3
# 20181103 4
# 20181103 5
# 20181104 0
# 20181104 1
# 20181104 2
# 20181104 3
# 20181104 4
# 20181104 5
# 20181105 0
# 20181105 1
# 20181105 2
# 20181105 3
# 20181105 4
# 20181105 5
# 20181106 0
# 20181106 1
# 20181106 2
# 20181106 3
# 20181106 4
# 20181106 5
# 20181107 0
# 20181107 1
# 20181107 2
# 20181107 3
# 20181107 4
# 20181107 5
# 20181108 0
# 20181108 1
# 20181108 2
# 20181108 3
# 20181108 4
# 20181108 5
# 20181109 0
# 20181109 1
# 20181109 2
# 20181109 3
# 20181109 4
# 20181109 5
# 20181110 0
# 20181110 1
# 20181110 2
# 20181110 3
# 20181110 4
# 20181110 5
# 20181111 0
# 20181111 1
# 20181111 2
# 20181111 3
# 20181111 4
# 20181111 5
# 20181112 0
# 20181112 1
# 20181112 2
# 20181112 3
# 20181112 4
# 20181112 5
# 20181113 0
# 20181113 1
# 20181113 2
# 20181113 3
# 20181113 4
# 20181113 5
# 20181114 0
# 20181114 1
# 20181114 2
# 20181114 3
# 20181114 4
# 20181114 5
# 20181115 0
# 20181115 1
# 20181115 2
# 20181115 3
# 20181115 4
# 20181115 5
# 20181116 0
# 20181116 1
# 20181116 2
# 20181116 3
# 20181116 4
# 20181116 5
# 20181117 0
# 20181117 1
# 20181117 2
# 20181117 3
# 20181117 4
# 20181117 5
# 20181118 0
# 20181118 1
# 20181118 2
# 20181118 3
# 20181118 4
# 20181118 5
# 20181119 0
# 20181119 1
# 20181119 2
# 20181119 3
# 20181119 4
# 20181119 5
# 20181120 0
# 20181120 1
# 20181120 2
# 20181120 3
# 20181120 4
# 20181120 5
# 20181121 0
# 20181121 1
# 20181121 2
# 20181121 3
# 20181121 4
# 20181121 5
# 20181122 0
# 20181122 1
# 20181122 2
# 20181122 3
# 20181122 4
# 20181122 5
# 20181123 0
# 20181123 1
# 20181123 2
# 20181123 3
# 20181123 4
# 20181123 5
# 20181124 0
# 20181124 1
# 20181124 2
# 20181124 3
# 20181124 4
# 20181124 5
# 20181125 0
# 20181125 1
# 20181125 2
# 20181125 3
# 20181125 4
# 20181125 5
# 20181126 0
# 20181126 1
# 20181126 2
# 20181126 3
# 20181126 4
# 20181126 5
# 20181127 0
# 20181127 1
# 20181127 2
# 20181127 3
# 20181127 4
# 20181127 5
# 20181128 0
# 20181128 1
# 20181128 2
# 20181128 3
# 20181128 4
# 20181128 5
# 20181129 0
# 20181129 1
# 20181129 2
# 20181129 3
# 20181129 4
# 20181129 5
# 20181130 0
# 20181130 1
# 20181130 2
# 20181130 3
# 20181130 4
# 20181130 5
# 20181201 0
# 20181201 1
# 20181201 2
# 20181201 3
# 20181201 4
# 20181201 5
# 20181202 0
# 20181202 1
# 20181202 2
# 20181202 3
# 20181202 4
# 20181202 5
# 20181203 0
# 20181203 1
# 20181203 2
# 20181203 3
# 20181203 4
# 20181203 5
# 20181204 0
# 20181204 1
# 20181204 2
# 20181204 3
# 20181204 4
# 20181204 5
# 20181205 0
# 20181205 1
# 20181205 2
# 20181205 3
# 20181205 4
# 20181205 5
# 20181206 0
# 20181206 1
# 20181206 2
# 20181206 3
# 20181206 4
# 20181206 5
# 20181207 0
# 20181207 1
# 20181207 2
# 20181207 3
# 20181207 4
# 20181207 5
# 20181208 0
# 20181208 1
# 20181208 2
# 20181208 3
# 20181208 4
# 20181208 5
# 20181209 0
# 20181209 1
# 20181209 2
# 20181209 3
# 20181209 4
# 20181209 5
# 20181210 0
# 20181210 1
# 20181210 2
# 20181210 3
# 20181210 4
# 20181210 5
# 20181211 0
# 20181211 1
# 20181211 2
# 20181211 3
# 20181211 4
# 20181211 5
# 20181212 0
# 20181212 1
# 20181212 2
# 20181212 3
# 20181212 4
# 20181212 5
# 20181213 0
# 20181213 1
# 20181213 2
# 20181213 3
# 20181213 4
# 20181213 5
# 20181214 0
# 20181214 1
# 20181214 2
# 20181214 3
# 20181214 4
# 20181214 5
# 20181215 0
# 20181215 1
# 20181215 2
# 20181215 3
# 20181215 4
# 20181215 5
# 20181216 0
# 20181216 1
# 20181216 2
# 20181216 3
# 20181216 4
# 20181216 5
# 20181217 0
# 20181217 1
# 20181217 2
# 20181217 3
# 20181217 4
# 20181217 5
# 20181218 0
# 20181218 1
# 20181218 2
# 20181218 3
# 20181218 4
# 20181218 5
# 20181219 0
# 20181219 1
# 20181219 2
# 20181219 3
# 20181219 4
# 20181219 5
# 20181220 0
# 20181220 1
# 20181220 2
# 20181220 3
# 20181220 4
# 20181220 5
# 20181221 0
# 20181221 1
# 20181221 2
# 20181221 3
# 20181221 4
# 20181221 5
# 20181222 0
# 20181222 1
# 20181222 2
# 20181222 3
# 20181222 4
# 20181222 5
# 20181223 0
# 20181223 1
# 20181223 2
# 20181223 3
# 20181223 4
# 20181223 5
# 20181224 0
# 20181224 1
# 20181224 2
# 20181224 3
# 20181224 4
# 20181224 5
# 20181225 0
# 20181225 1
# 20181225 2
# 20181225 3
# 20181225 4
# 20181225 5
# 20181226 0
# 20181226 1
# 20181226 2
# 20181226 3
# 20181226 4
# 20181226 5
# 20181227 0
# 20181227 1
# 20181227 2
# 20181227 3
# 20181227 4
# 20181227 5
# 20181228 0
# 20181228 1
# 20181228 2
# 20181228 3
# 20181228 4
# 20181228 5
# 20181229 0
# 20181229 1
# 20181229 2
# 20181229 3
# 20181229 4
# 20181229 5
# 20181230 0
# 20181230 1
# 20181230 2
# 20181230 3
# 20181230 4
# 20181230 5
# 20181231 0
# 20181231 1
# 20181231 2
# 20181231 3
# 20181231 4
# 20181231 5
# 20190101 0
# 20190101 1
# 20190101 2
# 20190101 3
# 20190101 4
# 20190101 5
# 20190102 0
# 20190102 1
# 20190102 2
# 20190102 3
# 20190102 4
# 20190102 5
# 20190103 0
# 20190103 1
# 20190103 2
# 20190103 3
# 20190103 4
# 20190103 5
# 20190104 0
# 20190104 1
# 20190104 2
# 20190104 3
# 20190104 4
# 20190104 5
# 20190105 0
# 20190105 1
# 20190105 2
# 20190105 3
# 20190105 4
# 20190105 5
# 20190106 0
# 20190106 1
# 20190106 2
# 20190106 3
# 20190106 4
# 20190106 5
# 20190107 0
# 20190107 1
# 20190107 2
# 20190107 3
# 20190107 4
# 20190107 5
# 20190108 0
# 20190108 1
# 20190108 2
# 20190108 3
# 20190108 4
# 20190108 5
# 20190109 0
# 20190109 1
# 20190109 2
# 20190109 3
# 20190109 4
# 20190109 5
# 20190110 0
# 20190110 1
# 20190110 2
# 20190110 3
# 20190110 4
# 20190110 5
# 20190111 0
# 20190111 1
# 20190111 2
# 20190111 3
# 20190111 4
# 20190111 5
# 20190112 0
# 20190112 1
# 20190112 2
# 20190112 3
# 20190112 4
# 20190112 5
# 20190113 0
# 20190113 1
# 20190113 2
# 20190113 3
# 20190113 4
# 20190113 5
# 20190114 0
# 20190114 1
# 20190114 2
# 20190114 3
# 20190114 4
# 20190114 5
# 20190115 0
# 20190115 1
# 20190115 2
# 20190115 3
# 20190115 4
# 20190115 5
# 20190116 0
# 20190116 1
# 20190116 2
# 20190116 3
# 20190116 4
# 20190116 5
# 20190117 0
# 20190117 1
# 20190117 2
# 20190117 3
# 20190117 4
# 20190117 5
# 20190118 0
# 20190118 1
# 20190118 2
# 20190118 3
# 20190118 4
# 20190118 5
# 20190119 0
# 20190119 1
# 20190119 2
# 20190119 3
# 20190119 4
# 20190119 5
# 20190120 0
# 20190120 1
# 20190120 2
# 20190120 3
# 20190120 4
# 20190120 5
# 20190121 0
# 20190121 1
# 20190121 2
# 20190121 3
# 20190121 4
# 20190121 5
# 20190122 0
# 20190122 1
# 20190122 2
# 20190122 3
# 20190122 4
# 20190122 5
# 20190123 0
# 20190123 1
# 20190123 2
# 20190123 3
# 20190123 4
# 20190123 5
# 20190124 0
# 20190124 1
# 20190124 2
# 20190124 3
# 20190124 4
# 20190124 5
# 20190125 0
# 20190125 1
# 20190125 2
# 20190125 3
# 20190125 4
# 20190125 5
# 20190126 0
# 20190126 1
# 20190126 2
# 20190126 3
# 20190126 4
# 20190126 5
# 20190127 0
# 20190127 1
# 20190127 2
# 20190127 3
# 20190127 4
# 20190127 5
# 20190128 0
# 20190128 1
# 20190128 2
# 20190128 3
# 20190128 4
# 20190128 5
# 20190129 0
# 20190129 1
# 20190129 2
# 20190129 3
# 20190129 4
# 20190129 5
# 20190130 0
# 20190130 1
# 20190130 2
# 20190130 3
# 20190130 4
# 20190130 5
# 20190131 0
# 20190131 1
# 20190131 2
# 20190131 3
# 20190131 4
# 20190131 5
# 20190201 0
# 20190201 1
# 20190201 2
# 20190201 3
# 20190201 4
# 20190201 5
# 20190202 0
# 20190202 1
# 20190202 2
# 20190202 3
# 20190202 4
# 20190202 5
# 20190203 0
# 20190203 1
# 20190203 2
# 20190203 3
# 20190203 4
# 20190203 5
# 20190204 0
# 20190204 1
# 20190204 2
# 20190204 3
# 20190204 4
# 20190204 5
# 20190205 0
# 20190205 1
# 20190205 2
# 20190205 3
# 20190205 4
# 20190205 5
# 20190206 0
# 20190206 1
# 20190206 2
# 20190206 3
# 20190206 4
# 20190206 5
# 20190207 0
# 20190207 1
# 20190207 2
# 20190207 3
# 20190207 4
# 20190207 5
# 20190208 0
# 20190208 1
# 20190208 2
# 20190208 3
# 20190208 4
# 20190208 5
# 20190209 0
# 20190209 1
# 20190209 2
# 20190209 3
# 20190209 4
# 20190209 5
# 20190210 0
# 20190210 1
# 20190210 2
# 20190210 3
# 20190210 4
# 20190210 5
# 20190211 0
# 20190211 1
# 20190211 2
# 20190211 3
# 20190211 4
# 20190211 5
# 20190212 0
# 20190212 1
# 20190212 2
# 20190212 3
# 20190212 4
# 20190212 5
# 20190213 0
# 20190213 1
# 20190213 2
# 20190213 3
# 20190213 4
# 20190213 5
# 20190214 0
# 20190214 1
# 20190214 2
# 20190214 3
# 20190214 4
# 20190214 5
# 20190215 0
# 20190215 1
# 20190215 2
# 20190215 3
# 20190215 4
# 20190215 5
# 20190216 0
# 20190216 1
# 20190216 2
# 20190216 3
# 20190216 4
# 20190216 5
# 20190217 0
# 20190217 1
# 20190217 2
# 20190217 3
# 20190217 4
# 20190217 5
# 20190218 0
# 20190218 1
# 20190218 2
# 20190218 3
# 20190218 4
# 20190218 5
# 20190219 0
# 20190219 1
# 20190219 2
# 20190219 3
# 20190219 4
# 20190219 5
# 20190220 0
# 20190220 1
# 20190220 2
# 20190220 3
# 20190220 4
# 20190220 5
# 20190221 0
# 20190221 1
# 20190221 2
# 20190221 3
# 20190221 4
# 20190221 5
# 20190222 0
# 20190222 1
# 20190222 2
# 20190222 3
# 20190222 4
# 20190222 5
# 20190223 0
# 20190223 1
# 20190223 2
# 20190223 3
# 20190223 4
# 20190223 5
# 20190224 0
# 20190224 1
# 20190224 2
# 20190224 3
# 20190224 4
# 20190224 5
# 20190225 0
# 20190225 1
# 20190225 2
# 20190225 3
# 20190225 4
# 20190225 5
# 20190226 0
# 20190226 1
# 20190226 2
# 20190226 3
# 20190226 4
# 20190226 5
# 20190227 0
# 20190227 1
# 20190227 2
# 20190227 3
# 20190227 4
# 20190227 5
# 20190228 0
# 20190228 1
# 20190228 2
# 20190228 3
# 20190228 4
# 20190228 5
# 20190301 0
# 20190301 1
# 20190301 2
# 20190301 3
# 20190301 4
# 20190301 5
# 20190302 0
# 20190302 1
# 20190302 2
# 20190302 3
# 20190302 4
# 20190302 5
# 20190303 0
# 20190303 1
# 20190303 2
# 20190303 3
# 20190303 4
# 20190303 5
# 20190304 0
# 20190304 1
# 20190304 2
# 20190304 3
# 20190304 4
# 20190304 5
# 20190305 0
# 20190305 1
# 20190305 2
# 20190305 3
# 20190305 4
# 20190305 5
# 20190306 0
# 20190306 1
# 20190306 2
# 20190306 3
# 20190306 4
# 20190306 5
# 20190307 0
# 20190307 1
# 20190307 2
# 20190307 3
# 20190307 4
# 20190307 5
# 20190308 0
# 20190308 1
# 20190308 2
# 20190308 3
# 20190308 4
# 20190308 5
# 20190309 0
# 20190309 1
# 20190309 2
# 20190309 3
# 20190309 4
# 20190309 5
# 20190310 0
# 20190310 1
# 20190310 2
# 20190310 3
# 20190310 4
# 20190310 5
# 20190311 0
# 20190311 1
# 20190311 2
# 20190311 3
# 20190311 4
# 20190311 5
# 20190312 0
# 20190312 1
# 20190312 2
# 20190312 3
# 20190312 4
# 20190312 5
# 20190313 0
# 20190313 1
# 20190313 2
# 20190313 3
# 20190313 4
# 20190313 5
# 20190314 0
# 20190314 1
# 20190314 2
# 20190314 3
# 20190314 4
# 20190314 5
# 20190315 0
# 20190315 1
# 20190315 2
# 20190315 3
# 20190315 4
# 20190315 5
# 20190316 0
# 20190316 1
# 20190316 2
# 20190316 3
# 20190316 4
# 20190316 5
# 20190317 0
# 20190317 1
# 20190317 2
# 20190317 3
# 20190317 4
# 20190317 5
# 20190318 0
# 20190318 1
# 20190318 2
# 20190318 3
# 20190318 4
# 20190318 5
# 20190319 0
# 20190319 1
# 20190319 2
# 20190319 3
# 20190319 4
# 20190319 5
# 20190320 0
# 20190320 1
# 20190320 2
# 20190320 3
# 20190320 4
# 20190320 5
# 20190321 0
# 20190321 1
# 20190321 2
# 20190321 3
# 20190321 4
# 20190321 5
# 20190322 0
# 20190322 1
# 20190322 2
# 20190322 3
# 20190322 4
# 20190322 5
# 20190323 0
# 20190323 1
# 20190323 2
# 20190323 3
# 20190323 4
# 20190323 5
# 20190324 0
# 20190324 1
# 20190324 2
# 20190324 3
# 20190324 4
# 20190324 5
# 20190325 0
# 20190325 1
# 20190325 2
# 20190325 3
# 20190325 4
# 20190325 5
# 20190326 0
# 20190326 1
# 20190326 2
# 20190326 3
# 20190326 4
# 20190326 5
# 20190327 0
# 20190327 1
# 20190327 2
# 20190327 3
# 20190327 4
# 20190327 5
# 20190328 0
# 20190328 1
# 20190328 2
# 20190328 3
# 20190328 4
# 20190328 5
# 20190329 0
# 20190329 1
# 20190329 2
# 20190329 3
# 20190329 4
# 20190329 5
# 20190330 0
# 20190330 1
# 20190330 2
# 20190330 3
# 20190330 4
# 20190330 5
# 20190331 0
# 20190331 1
# 20190331 2
# 20190331 3
# 20190331 4
# 20190331 5
# 20190401 0
# 20190401 1
# 20190401 2
# 20190401 3
# 20190401 4
# 20190401 5
# 20190402 0
# 20190402 1
# 20190402 2
# 20190402 3
# 20190402 4
# 20190402 5
# 20190403 0
# 20190403 1
# 20190403 2
# 20190403 3
# 20190403 4
# 20190403 5
# 20190404 0
# 20190404 1
# 20190404 2
# 20190404 3
# 20190404 4
# 20190404 5
# 20190405 0
# 20190405 1
# 20190405 2
# 20190405 3
# 20190405 4
# 20190405 5
# 20190406 0
# 20190406 1
# 20190406 2
# 20190406 3
# 20190406 4
# 20190406 5
# 20190407 0
# 20190407 1
# 20190407 2
# 20190407 3
# 20190407 4
# 20190407 5
# 20190408 0
# 20190408 1
# 20190408 2
# 20190408 3
# 20190408 4
# 20190408 5
# 20190409 0
# 20190409 1
# 20190409 2
# 20190409 3
# 20190409 4
# 20190409 5
# 20190410 0
# 20190410 1
# 20190410 2
# 20190410 3
# 20190410 4
# 20190410 5
# 20190411 0
# 20190411 1
# 20190411 2
# 20190411 3
# 20190411 4
# 20190411 5
# 20190412 0
# 20190412 1
# 20190412 2
# 20190412 3
# 20190412 4
# 20190412 5
# 20190413 0
# 20190413 1
# 20190413 2
# 20190413 3
# 20190413 4
# 20190413 5
# 20190414 0
# 20190414 1
# 20190414 2
# 20190414 3
# 20190414 4
# 20190414 5
# 20190415 0
# 20190415 1
# 20190415 2
# 20190415 3
# 20190415 4
# 20190415 5
# 20190416 0
# 20190416 1
# 20190416 2
# 20190416 3
# 20190416 4
# 20190416 5
# 20190417 0
# 20190417 1
# 20190417 2
# 20190417 3
# 20190417 4
# 20190417 5
# 20190418 0
# 20190418 1
# 20190418 2
# 20190418 3
# 20190418 4
# 20190418 5
# 20190419 0
# 20190419 1
# 20190419 2
# 20190419 3
# 20190419 4
# 20190419 5
# 20190420 0
# 20190420 1
# 20190420 2
# 20190420 3
# 20190420 4
# 20190420 5
# 20190421 0
# 20190421 1
# 20190421 2
# 20190421 3
# 20190421 4
# 20190421 5
# 20190422 0
# 20190422 1
# 20190422 2
# 20190422 3
# 20190422 4
# 20190422 5
# 20190423 0
# 20190423 1
# 20190423 2
# 20190423 3
# 20190423 4
# 20190423 5
# 20190424 0
# 20190424 1
# 20190424 2
# 20190424 3
# 20190424 4
# 20190424 5
# 20190425 0
# 20190425 1
# 20190425 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-8df13607a762> in <module>
#      37                 title = dom.find('h3', {'id':'articleTitle'}).text.strip()
#      38                 #기사작성일
# ---> 39                 date = dom.find_all('span', {'class':'t11'})[0].text.strip()
#      40                 #본문
#      41                 body = dom.find_all('div',{'id':'articleBodyContents'})[0].text.replace(
#
# ~/anaconda3/envs/jhenv/lib/python3.7/site-packages/bs4/element.py in find_all(self, name, attrs, recursive, text, limit, **kwargs)
#    1781         if not recursive:
#    1782             generator = self.children
# -> 1783         return self._find_all(name, attrs, text, limit, generator, **kwargs)
#    1784     findAll = find_all       # BS3
#    1785     findChildren = find_all  # BS2
#
# ~/anaconda3/envs/jhenv/lib/python3.7/site-packages/bs4/element.py in _find_all(self, name, attrs, text, limit, generator, **kwargs)
#     776                 break
#     777             if i:
# --> 778                 found = strainer.search(i)
#     779                 if found:
#     780                     results.append(found)
#
# ~/anaconda3/envs/jhenv/lib/python3.7/site-packages/bs4/element.py in search(self, markup)
#    2050         elif isinstance(markup, Tag):
#    2051             if not self.text or self.name or self.attrs:
# -> 2052                 found = self.search_tag(markup)
#    2053         # If it's text, make sure the text matches.
#    2054         elif isinstance(markup, NavigableString) or \
#
# ~/anaconda3/envs/jhenv/lib/python3.7/site-packages/bs4/element.py in search_tag(self, markup_name, markup_attrs)
#    2013                                 markup_attr_map[k] = v
#    2014                     attr_value = markup_attr_map.get(attr)
# -> 2015                     if not self._matches(attr_value, match_against):
#    2016                         match = False
#    2017                         break
#
# ~/anaconda3/envs/jhenv/lib/python3.7/site-packages/bs4/element.py in _matches(self, markup, match_against, already_tried)
#    2073             # attribute, but maybe we match the attribute value when
#    2074             # considered as a string.
# -> 2075             if self._matches(' '.join(markup), match_against):
#    2076                 return True
#    2077             return False
#
# ~/anaconda3/envs/jhenv/lib/python3.7/site-packages/bs4/element.py in _matches(self, markup, match_against, already_tried)
#    2064         # print(u"Matching %s against %s" % (markup, match_against))
#    2065         result = False
# -> 2066         if isinstance(markup, list) or isinstance(markup, tuple):
#    2067             # This should only happen when searching a multi-valued attribute
#    2068             # like 'class'.
#
# KeyboardInterrupt:

# %%
import pandas as pd
pd.to_datetime('20200801', format='%Y%m%d')
# Out:
# Timestamp('2020-08-01 00:00:00')

# %%
from datetime import datetime, timedelta 

start_date = datetime.strptime('20190425', '%Y%m%d') 
end_date = datetime.today()
str_date_list = [] 
while start_date.strftime('%Y%m%d') != end_date.strftime('%Y%m%d'): 
    str_date_list.append(start_date.strftime('%Y%m%d')) 
    start_date += timedelta(days=1)

# %%
str_date_list[:3]
# Out:
# ['20190425', '20190426', '20190427']

# %%
import sqlite3

conn = sqlite3.connect('news.db')
cur = conn.cursor()

# %%
for j in str_date_list:
    for i in range(6):
        print(j,i)
        url = 'https://news.naver.com/main/ranking/popularDay.nhn'

        params = {
            'rankingType': 'popular_day',
        }

        params['sectionId'] = '10'+str(i)
        params['date']=j

        headers = {
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'
        }

        resp = download(url, params=params, headers=headers)
        if resp.status_code!=200:
            continue
        dom = BeautifulSoup(resp.content, 'lxml')
        
        
        #뉴스링크 수집
        urlst = []
        for _ in dom.find_all('div',{'class':'ranking_headline'}):
            if _.a['href'] not in urlst:
                urlst.append(_.a['href'])
        
        for _ in urlst:
            newslink = urljoin(url, _)
            resp = download(newslink, headers=headers)
            if resp.status_code!=200:
                continue
            dom = BeautifulSoup(resp.content, 'html.parser')
            if dom.find_all('a',{'class':'media_end_head_autosummary_button _toggle_btn nclicks(sum_summary)'}) != []:
                #제목
                title = dom.find('h3', {'id':'articleTitle'}).text.strip()
                #기사작성일
                date = dom.find_all('span', {'class':'t11'})[0].text.strip()
                #본문
                body = dom.find_all('div',{'id':'articleBodyContents'})[0].text.replace(
                    '\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}\n\n','').replace(
                    '<br/>','').strip()

                if re.search("▶", body):
                    body = body[:re.search("▶", body).start()]

                parsed = (urlparse(newslink)).query.split('&')
                oid = parsed[1]
                aid = parsed[2]

                oidno = re.search(re.compile(r'[^oid=]{3}'), oid).group(0)
                aidno = re.search(re.compile(r'[^aid=]{10}'), aid).group(0)

                sumurl = 'https://tts.news.naver.com/article/'+oidno+'/'+aidno+'/summary'
                sumresp = download(sumurl)
                if sumresp.status_code!=200:
                    continue
                json = sumresp.json()
                #요약
                summary = json['summary'].replace('<br/>','')

                cur.execute('INSERT INTO navernews VALUES(NULL,?,?,?,?,?)',[title,date,body,summary,newslink])
                conn.commit()
# Out:
# 20190425 0
# 20190425 1
# 20190425 2
# 20190425 3
# 20190425 4
# 20190425 5
# 20190426 0
# 20190426 1
# 20190426 2
# 20190426 3
# 20190426 4
# 20190426 5
# 20190427 0
# 20190427 1
# 20190427 2
# 20190427 3
# 20190427 4
# 20190427 5
# 20190428 0
# 20190428 1
# 20190428 2
# 20190428 3
# 20190428 4
# 20190428 5
# 20190429 0
# 20190429 1
# 20190429 2
# 20190429 3
# 20190429 4
# 20190429 5
# 20190430 0
# 20190430 1
# 20190430 2
# 20190430 3
# 20190430 4
# 20190430 5
# 20190501 0
# 20190501 1
# 20190501 2
# 20190501 3
# 20190501 4
# 20190501 5
# 20190502 0
# 20190502 1
# 20190502 2
# 20190502 3
# 20190502 4
# 20190502 5
# 20190503 0
# 20190503 1
# 20190503 2
# 20190503 3
# 20190503 4
# 20190503 5
# 20190504 0
# 20190504 1
# 20190504 2
# 20190504 3
# 20190504 4
# 20190504 5
# 20190505 0
# 20190505 1
# 20190505 2
# 20190505 3
# 20190505 4
# 20190505 5
# 20190506 0
# 20190506 1
# 20190506 2
# 20190506 3
# 20190506 4
# 20190506 5
# 20190507 0
# 20190507 1
# 20190507 2
# 20190507 3
# 20190507 4
# 20190507 5
# 20190508 0
# 20190508 1
# 20190508 2
# 20190508 3
# 20190508 4
# 20190508 5
# 20190509 0
# 20190509 1
# 20190509 2
# 20190509 3
# 20190509 4
# 20190509 5
# 20190510 0
# 20190510 1
# 20190510 2
# 20190510 3
# 20190510 4
# 20190510 5
# 20190511 0
# 20190511 1
# 20190511 2
# 20190511 3
# 20190511 4
# 20190511 5
# 20190512 0
# 20190512 1
# 20190512 2
# 20190512 3
# 20190512 4
# 20190512 5
# 20190513 0
# 20190513 1
# 20190513 2
# 20190513 3
# 20190513 4
# 20190513 5
# 20190514 0
# 20190514 1
# 20190514 2
# 20190514 3
# 20190514 4
# 20190514 5
# 20190515 0
# 20190515 1
# 20190515 2
# 20190515 3
# 20190515 4
# 20190515 5
# 20190516 0
# 20190516 1
# 20190516 2
# 20190516 3
# 20190516 4
# 20190516 5
# 20190517 0
# 20190517 1
# 20190517 2
# 20190517 3
# 20190517 4
# 20190517 5
# 20190518 0
# 20190518 1
# 20190518 2
# 20190518 3
# 20190518 4
# 20190518 5
# 20190519 0
# 20190519 1
# 20190519 2
# 20190519 3
# 20190519 4
# 20190519 5
# 20190520 0
# 20190520 1
# 20190520 2
# 20190520 3
# 20190520 4
# 20190520 5
# 20190521 0
# 20190521 1
# 20190521 2
# 20190521 3
# 20190521 4
# 20190521 5
# 20190522 0
# 20190522 1
# 20190522 2
# 20190522 3
# 20190522 4
# 20190522 5
# 20190523 0
# 20190523 1
# 20190523 2
# 20190523 3
# 20190523 4
# 20190523 5
# 20190524 0
# 20190524 1
# 20190524 2
# 20190524 3
# 20190524 4
# 20190524 5
# 20190525 0
# 20190525 1
# 20190525 2
# 20190525 3
# 20190525 4
# 20190525 5
# 20190526 0
# 20190526 1
# 20190526 2
# 20190526 3
# 20190526 4
# 20190526 5
# 20190527 0
# 20190527 1
# 20190527 2
# 20190527 3
# 20190527 4
# 20190527 5
# 20190528 0
# 20190528 1
# 20190528 2
# 20190528 3
# 20190528 4
# 20190528 5
# 20190529 0
# 20190529 1
# 20190529 2
# 20190529 3
# 20190529 4
# 20190529 5
# 20190530 0
# 20190530 1
# 20190530 2
# 20190530 3
# 20190530 4
# 20190530 5
# 20190531 0
# 20190531 1
# 20190531 2
# 20190531 3
# 20190531 4
# 20190531 5
# 20190601 0
# 20190601 1
# 20190601 2
# 20190601 3
# 20190601 4
# 20190601 5
# 20190602 0
# 20190602 1
# 20190602 2
# 20190602 3
# 20190602 4
# 20190602 5
# 20190603 0
# 20190603 1
# 20190603 2
# 20190603 3
# 20190603 4
# 20190603 5
# 20190604 0
# 20190604 1
# 20190604 2
# 20190604 3
# 20190604 4
# 20190604 5
# 20190605 0
# 20190605 1
# 20190605 2
# 20190605 3
# 20190605 4
# 20190605 5
# 20190606 0
# 20190606 1
# 20190606 2
# 20190606 3
# 20190606 4
# 20190606 5
# 20190607 0
# 20190607 1
# 20190607 2
# 20190607 3
# 20190607 4
# 20190607 5
# 20190608 0
# 20190608 1
# 20190608 2
# 20190608 3
# 20190608 4
# 20190608 5
# 20190609 0
# 20190609 1
# 20190609 2
# 20190609 3
# 20190609 4
# 20190609 5
# 20190610 0
# 20190610 1
# 20190610 2
# 20190610 3
# 20190610 4
# 20190610 5
# 20190611 0
# 20190611 1
# 20190611 2
# 20190611 3
# 20190611 4
# 20190611 5
# 20190612 0
# 20190612 1
# 20190612 2
# 20190612 3
# 20190612 4
# 20190612 5
# 20190613 0
# 20190613 1
# 20190613 2
# 20190613 3
# 20190613 4
# 20190613 5
# 20190614 0
# 20190614 1
# 20190614 2
# 20190614 3
# 20190614 4
# 20190614 5
# 20190615 0
# 20190615 1
# 20190615 2
# 20190615 3
# 20190615 4
# 20190615 5
# 20190616 0
# 20190616 1
# 20190616 2
# 20190616 3
# 20190616 4
# 20190616 5
# 20190617 0
# 20190617 1
# 20190617 2
# 20190617 3
# 20190617 4
# 20190617 5
# 20190618 0
# 20190618 1
# 20190618 2
# 20190618 3
# 20190618 4
# 20190618 5
# 20190619 0
# 20190619 1
# 20190619 2
# 20190619 3
# 20190619 4
# 20190619 5
# 20190620 0
# 20190620 1
# 20190620 2
# 20190620 3
# 20190620 4
# 20190620 5
# 20190621 0
# 20190621 1
# 20190621 2
# 20190621 3
# 20190621 4
# 20190621 5
# 20190622 0
# 20190622 1
# 20190622 2
# 20190622 3
# 20190622 4
# 20190622 5
# 20190623 0
# 20190623 1
# 20190623 2
# 20190623 3
# 20190623 4
# 20190623 5
# 20190624 0
# 20190624 1
# 20190624 2
# 20190624 3
# 20190624 4
# 20190624 5
# 20190625 0
# 20190625 1
# 20190625 2
# 20190625 3
# 20190625 4
# 20190625 5
# 20190626 0
# 20190626 1
# 20190626 2
# 20190626 3
# 20190626 4
# 20190626 5
# 20190627 0
# 20190627 1
# 20190627 2
# 20190627 3
# 20190627 4
# 20190627 5
# 20190628 0
# 20190628 1
# 20190628 2
# 20190628 3
# 20190628 4
# 20190628 5
# 20190629 0
# 20190629 1
# 20190629 2
# 20190629 3
# 20190629 4
# 20190629 5
# 20190630 0
# 20190630 1
# 20190630 2
# 20190630 3
# 20190630 4
# 20190630 5
# 20190701 0
# 20190701 1
# 20190701 2
# 20190701 3
# 20190701 4
# 20190701 5
# 20190702 0
# 20190702 1
# 20190702 2
# 20190702 3
# 20190702 4
# 20190702 5
# 20190703 0
# 20190703 1
# 20190703 2
# 20190703 3
# 20190703 4
# 20190703 5
# 20190704 0
# 20190704 1
# 20190704 2
# 20190704 3
# 20190704 4
# 20190704 5
# 20190705 0
# 20190705 1
# 20190705 2
# 20190705 3
# 20190705 4
# 20190705 5
# 20190706 0
# 20190706 1
# 20190706 2
# 20190706 3
# 20190706 4
# 20190706 5
# 20190707 0
# 20190707 1
# 20190707 2
# 20190707 3
# 20190707 4
# 20190707 5
# 20190708 0
# 20190708 1
# 20190708 2
# 20190708 3
# 20190708 4
# 20190708 5
# 20190709 0
# 20190709 1
# 20190709 2
# 20190709 3
# 20190709 4
# 20190709 5
# 20190710 0
# 20190710 1
# 20190710 2
# 20190710 3
# 20190710 4
# 20190710 5
# 20190711 0
# 20190711 1
# 20190711 2
# 20190711 3
# 20190711 4
# 20190711 5
# 20190712 0
# 20190712 1
# 20190712 2
# 20190712 3
# 20190712 4
# 20190712 5
# 20190713 0
# 20190713 1
# 20190713 2
# 20190713 3
# 20190713 4
# 20190713 5
# 20190714 0
# 20190714 1
# 20190714 2
# 20190714 3
# 20190714 4
# 20190714 5
# 20190715 0
# 20190715 1
# 20190715 2
# 20190715 3
# 20190715 4
# 20190715 5
# 20190716 0
# 20190716 1
# 20190716 2
# 20190716 3
# 20190716 4
# 20190716 5
# 20190717 0
# 20190717 1
# 20190717 2
# 20190717 3
# 20190717 4
# 20190717 5
# 20190718 0
# 20190718 1
# 20190718 2
# 20190718 3
# 20190718 4
# 20190718 5
# 20190719 0
# 20190719 1
# 20190719 2
# 20190719 3
# 20190719 4
# 20190719 5
# 20190720 0
# 20190720 1
# 20190720 2
# 20190720 3
# 20190720 4
# 20190720 5
# 20190721 0
# 20190721 1
# 20190721 2
# 20190721 3
# 20190721 4
# 20190721 5
# 20190722 0
# 20190722 1
# 20190722 2
# 20190722 3
# 20190722 4
# 20190722 5
# 20190723 0
# 20190723 1
# 20190723 2
# 20190723 3
# 20190723 4
# 20190723 5
# 20190724 0
# 20190724 1
# 20190724 2
# 20190724 3
# 20190724 4
# 20190724 5
# 20190725 0
# 20190725 1
# 20190725 2
# 20190725 3
# 20190725 4
# 20190725 5
# 20190726 0
# 20190726 1
# 20190726 2
# 20190726 3
# 20190726 4
# 20190726 5
# 20190727 0
# 20190727 1
# 20190727 2
# 20190727 3
# 20190727 4
# 20190727 5
# 20190728 0
# 20190728 1
# 20190728 2
# 20190728 3
# 20190728 4
# 20190728 5
# 20190729 0
# 20190729 1
# 20190729 2
# 20190729 3
# 20190729 4
# 20190729 5
# 20190730 0
# 20190730 1
# 20190730 2
# 20190730 3
# 20190730 4
# 20190730 5
# 20190731 0
# 20190731 1
# 20190731 2
# 20190731 3
# 20190731 4
# 20190731 5
# 20190801 0
# 20190801 1
# 20190801 2
# 20190801 3
# 20190801 4
# 20190801 5
# 20190802 0
# 20190802 1
# 20190802 2
# 20190802 3
# 20190802 4
# 20190802 5
# 20190803 0
# 20190803 1
# 20190803 2
# 20190803 3
# 20190803 4
# 20190803 5
# 20190804 0
# 20190804 1
# 20190804 2
# 20190804 3
# 20190804 4
# 20190804 5
# 20190805 0
# 20190805 1
# 20190805 2
# 20190805 3
# 20190805 4
# 20190805 5
# 20190806 0
# 20190806 1
# 20190806 2
# 20190806 3
# 20190806 4
# 20190806 5
# 20190807 0
# 20190807 1
# 20190807 2
# 20190807 3
# 20190807 4
# 20190807 5
# 20190808 0
# 20190808 1
# 20190808 2
# 20190808 3
# 20190808 4
# 20190808 5
# 20190809 0
# 20190809 1
# 20190809 2
# 20190809 3
# 20190809 4
# 20190809 5
# 20190810 0
# 20190810 1
# 20190810 2
# 20190810 3
# 20190810 4
# 20190810 5
# 20190811 0
# 20190811 1
# 20190811 2
# 20190811 3
# 20190811 4
# 20190811 5
# 20190812 0
# 20190812 1
# 20190812 2
# 20190812 3
# 20190812 4
# 20190812 5
# 20190813 0
# 20190813 1
# 20190813 2
# 20190813 3
# 20190813 4
# 20190813 5
# 20190814 0
# 20190814 1
# 20190814 2
# 20190814 3
# 20190814 4
# 20190814 5
# 20190815 0
# 20190815 1
# 20190815 2
# 20190815 3
# 20190815 4
# 20190815 5
# 20190816 0
# 20190816 1
# 20190816 2
# 20190816 3
# 20190816 4
# 20190816 5
# 20190817 0
# 20190817 1
# 20190817 2
# 20190817 3
# 20190817 4
# 20190817 5
# 20190818 0
# 20190818 1
# 20190818 2
# 20190818 3
# 20190818 4
# 20190818 5
# 20190819 0
# 20190819 1
# 20190819 2
# 20190819 3
# 20190819 4
# 20190819 5
# 20190820 0
# 20190820 1
# 20190820 2
# 20190820 3
# 20190820 4
# 20190820 5
# 20190821 0
# 20190821 1
# 20190821 2
# 20190821 3
# 20190821 4
# 20190821 5
# 20190822 0
# 20190822 1
# 20190822 2
# 20190822 3
# 20190822 4
# 20190822 5
# 20190823 0
# 20190823 1
# 20190823 2
# 20190823 3
# 20190823 4
# 20190823 5
# 20190824 0
# 20190824 1
# 20190824 2
# 20190824 3
# 20190824 4
# 20190824 5
# 20190825 0
# 20190825 1
# 20190825 2
# 20190825 3
# 20190825 4
# 20190825 5
# 20190826 0
# 20190826 1
# 20190826 2
# 20190826 3
# 20190826 4
# 20190826 5
# 20190827 0
# 20190827 1
# 20190827 2
# 20190827 3
# 20190827 4
# 20190827 5
# 20190828 0
# 20190828 1
# 20190828 2
# 20190828 3
# 20190828 4
# 20190828 5
# 20190829 0
# 20190829 1
# 20190829 2
# 20190829 3
# 20190829 4
# 20190829 5
# 20190830 0
# 20190830 1
# 20190830 2
# 20190830 3
# 20190830 4
# 20190830 5
# 20190831 0
# 20190831 1
# 20190831 2
# 20190831 3
# 20190831 4
# 20190831 5
# 20190901 0
# 20190901 1
# 20190901 2
# 20190901 3
# 20190901 4
# 20190901 5
# 20190902 0
# 20190902 1
# 20190902 2
# 20190902 3
# 20190902 4
# 20190902 5
# 20190903 0
# 20190903 1
# 20190903 2
# 20190903 3
# 20190903 4
# 20190903 5
# 20190904 0
# 20190904 1
# 20190904 2
# 20190904 3
# 20190904 4
# 20190904 5
# 20190905 0
# 20190905 1
# 20190905 2
# 20190905 3
# 20190905 4
# 20190905 5
# 20190906 0
# 20190906 1
# 20190906 2
# 20190906 3
# 20190906 4
# 20190906 5
# 20190907 0
# 20190907 1
# 20190907 2
# 20190907 3
# 20190907 4
# 20190907 5
# 20190908 0
# 20190908 1
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-1-327f296c2898> in download(url, params, headers, method, limit)
#      23                headers=headers)
# ---> 24         resp.raise_for_status()
#      25     except HTTPError as e:
#
# ~/anaconda3/envs/jhenv/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#
# HTTPError: 500 Server Error: Internal Server Error for url: https://tts.news.naver.com/article/015/0004205767/summary
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-8df13607a762> in <module>
#      54
#      55                 sumurl = 'https://tts.news.naver.com/article/'+oidno+'/'+aidno+'/summary'
# ---> 56                 sumresp = download(sumurl)
#      57                 if sumresp.status_code!=200:
#      58                     continue
#
# <ipython-input-1-327f296c2898> in download(url, params, headers, method, limit)
#      25     except HTTPError as e:
#      26         if limit > 0 and e.response.status_code >= 500:
# ---> 27             print(limit, resp.requests.url)
#      28             time.sleep(random.random()*5) # => random
#      29             resp = download(url, params, headers, method, limit-1)
#
# AttributeError: 'Response' object has no attribute 'requests'

# %%
import pandas as pd
pd.to_datetime('20200801', format='%Y%m%d')

from datetime import datetime, timedelta 

start_date = datetime.strptime('20200105', '%Y%m%d') 
end_date = datetime.today()
str_date_list = [] 
while start_date.strftime('%Y%m%d') != end_date.strftime('%Y%m%d'): 
    str_date_list.append(start_date.strftime('%Y%m%d')) 
    start_date += timedelta(days=1)

# %%
str_date_list[:3]
# Out:
# ['20200105', '20200106', '20200107']

# %%
import sqlite3

conn = sqlite3.connect('news.db')
cur = conn.cursor()

# %%
for j in str_date_list:
    for i in range(6):
        print(j,i)
        url = 'https://news.naver.com/main/ranking/popularDay.nhn'

        params = {
            'rankingType': 'popular_day',
        }

        params['sectionId'] = '10'+str(i)
        params['date']=j

        headers = {
            'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'
        }

        resp = download(url, params=params, headers=headers)
        if resp.status_code!=200:
            continue
        dom = BeautifulSoup(resp.content, 'lxml')
        
        
        #뉴스링크 수집
        urlst = []
        for _ in dom.find_all('div',{'class':'ranking_headline'}):
            if _.a['href'] not in urlst:
                urlst.append(_.a['href'])
        
        for _ in urlst:
            newslink = urljoin(url, _)
            resp = download(newslink, headers=headers)
            if resp.status_code!=200:
                continue
            dom = BeautifulSoup(resp.content, 'html.parser')
            if dom.find_all('a',{'class':'media_end_head_autosummary_button _toggle_btn nclicks(sum_summary)'}) != []:
                #제목
                title = dom.find('h3', {'id':'articleTitle'}).text.strip()
                #기사작성일
                date = dom.find_all('span', {'class':'t11'})[0].text.strip()
                #본문
                body = dom.find_all('div',{'id':'articleBodyContents'})[0].text.replace(
                    '\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}\n\n','').replace(
                    '<br/>','').strip()

                if re.search("▶", body):
                    body = body[:re.search("▶", body).start()]

                parsed = (urlparse(newslink)).query.split('&')
                oid = parsed[1]
                aid = parsed[2]

                oidno = re.search(re.compile(r'[^oid=]{3}'), oid).group(0)
                aidno = re.search(re.compile(r'[^aid=]{10}'), aid).group(0)

                sumurl = 'https://tts.news.naver.com/article/'+oidno+'/'+aidno+'/summary'
                sumresp = download(sumurl)
                if sumresp.status_code!=200:
                    continue
                json = sumresp.json()
                #요약
                summary = json['summary'].replace('<br/>','')

                cur.execute('INSERT INTO navernews VALUES(NULL,?,?,?,?,?)',[title,date,body,summary,newslink])
                conn.commit()
# Out:
# 20200105 0
# 20200105 1
# 20200105 2
# 20200105 3
# 20200105 4
# 20200105 5
# 20200106 0
# 20200106 1
# 20200106 2
# 20200106 3
# 20200106 4
# 20200106 5
# 20200107 0
# 20200107 1
# 20200107 2
# 20200107 3
# 20200107 4
# 20200107 5
# 20200108 0
# 20200108 1
# 20200108 2
# 20200108 3
# 20200108 4
# 20200108 5
# 20200109 0
# 20200109 1
# 20200109 2
# 20200109 3
# 20200109 4
# 20200109 5
# 20200110 0
# 20200110 1
# 20200110 2
# 20200110 3
# 20200110 4
# 20200110 5
# 20200111 0
# 20200111 1
# 20200111 2
# 20200111 3
# 20200111 4
# 20200111 5
# 20200112 0
# 20200112 1
# 20200112 2
# 20200112 3
# 20200112 4
# 20200112 5
# 20200113 0
# 20200113 1
# 20200113 2
# 20200113 3
# 20200113 4
# 20200113 5
# 20200114 0
# 20200114 1
# 20200114 2
# 20200114 3
# 20200114 4
# 20200114 5
# 20200115 0
# 20200115 1
# 20200115 2
# 20200115 3
# 20200115 4
# 20200115 5
# 20200116 0
# 20200116 1
# 20200116 2
# 20200116 3
# 20200116 4
# 20200116 5
# 20200117 0
# 20200117 1
# 20200117 2
# 20200117 3
# 20200117 4
# 20200117 5
# 20200118 0
# 20200118 1
# 20200118 2
# 20200118 3
# 20200118 4
# 20200118 5
# 20200119 0
# 20200119 1
# 20200119 2
# 20200119 3
# 20200119 4
# 20200119 5
# 20200120 0
# 20200120 1
# 20200120 2
# 20200120 3
# 20200120 4
# 20200120 5
# 20200121 0
# 20200121 1
# 20200121 2
# 20200121 3
# 20200121 4
# 20200121 5
# 20200122 0
# 20200122 1
# 20200122 2
# 20200122 3
# 20200122 4
# 20200122 5
# 20200123 0
# 20200123 1
# 20200123 2
# 20200123 3
# 20200123 4
# 20200123 5
# 20200124 0
# 20200124 1
# 20200124 2
# 20200124 3
# 20200124 4
# 20200124 5
# 20200125 0
# 20200125 1
# 20200125 2
# 20200125 3
# 20200125 4
# 20200125 5
# 20200126 0
# 20200126 1
# 20200126 2
# 20200126 3
# 20200126 4
# 20200126 5
# 20200127 0
# 20200127 1
# 20200127 2
# 20200127 3
# 20200127 4
# 20200127 5
# 20200128 0
# 20200128 1
# 20200128 2
# 20200128 3
# 20200128 4
# 20200128 5
# 20200129 0
# 20200129 1
# 20200129 2
# 20200129 3
# 20200129 4
# 20200129 5
# 20200130 0
# 20200130 1
# 20200130 2
# 20200130 3
# 20200130 4
# 20200130 5
# 20200131 0
# 20200131 1
# 20200131 2
# 20200131 3
# 20200131 4
# 20200131 5
# 20200201 0
# 20200201 1
# 20200201 2
# 20200201 3
# 20200201 4
# 20200201 5
# 20200202 0
# 20200202 1
# 20200202 2
# 20200202 3
# 20200202 4
# 20200202 5
# 20200203 0
# 20200203 1
# 20200203 2
# 20200203 3
# 20200203 4
# 20200203 5
# 20200204 0
# 20200204 1
# 20200204 2
# 20200204 3
# 20200204 4
# 20200204 5
# 20200205 0
# 20200205 1
# 20200205 2
# 20200205 3
# 20200205 4
# 20200205 5
# 20200206 0
# 20200206 1
# 20200206 2
# 20200206 3
# 20200206 4
# 20200206 5
# 20200207 0
# 20200207 1
# 20200207 2
# 3 https://tts.news.naver.com/article/020/0003268295/summary
# 2 https://tts.news.naver.com/article/020/0003268295/summary
# 1 https://tts.news.naver.com/article/020/0003268295/summary
# 20200207 3
# 20200207 4
# 20200207 5
# 20200208 0
# 20200208 1
# 20200208 2
# 20200208 3
# 20200208 4
# 20200208 5
# 20200209 0
# 20200209 1
# 20200209 2
# 20200209 3
# 20200209 4
# 20200209 5
# 20200210 0
# 20200210 1
# 20200210 2
# 20200210 3
# 20200210 4
# 20200210 5
# 20200211 0
# 20200211 1
# 20200211 2
# 20200211 3
# 20200211 4
# 20200211 5
# 20200212 0
# 20200212 1
# 20200212 2
# 20200212 3
# 20200212 4
# 20200212 5
# 20200213 0
# 20200213 1
# 20200213 2
# 20200213 3
# 20200213 4
# 20200213 5
# 20200214 0
# 20200214 1
# 20200214 2
# 20200214 3
# 20200214 4
# 20200214 5
# 20200215 0
# 20200215 1
# 20200215 2
# 20200215 3
# 20200215 4
# 20200215 5
# 20200216 0
# 20200216 1
# 20200216 2
# 20200216 3
# 20200216 4
# 20200216 5
# 20200217 0
# 20200217 1
# 20200217 2
# 20200217 3
# 20200217 4
# 20200217 5
# 20200218 0
# 20200218 1
# 20200218 2
# 20200218 3
# 20200218 4
# 20200218 5
# 20200219 0
# 20200219 1
# 20200219 2
# 20200219 3
# 20200219 4
# 20200219 5
# 20200220 0
# 20200220 1
# 20200220 2
# 20200220 3
# 20200220 4
# 20200220 5
# 20200221 0
# 20200221 1
# 20200221 2
# 20200221 3
# 20200221 4
# 20200221 5
# 20200222 0
# 20200222 1
# 20200222 2
# 20200222 3
# 20200222 4
# 20200222 5
# 20200223 0
# 20200223 1
# 20200223 2
# 20200223 3
# 20200223 4
# 20200223 5
# 20200224 0
# 20200224 1
# 20200224 2
# 20200224 3
# 20200224 4
# 20200224 5
# 20200225 0
# 20200225 1
# 20200225 2
# 20200225 3
# 20200225 4
# 20200225 5
# 20200226 0
# 20200226 1
# 20200226 2
# 20200226 3
# 20200226 4
# 20200226 5
# 20200227 0
# 20200227 1
# 20200227 2
# 20200227 3
# 20200227 4
# 20200227 5
# 20200228 0
# 20200228 1
# 20200228 2
# 20200228 3
# 20200228 4
# 20200228 5
# 20200229 0
# 20200229 1
# 20200229 2
# 20200229 3
# 20200229 4
# 20200229 5
# 20200301 0
# 20200301 1
# 20200301 2
# 20200301 3
# 20200301 4
# 20200301 5
# 20200302 0
# 20200302 1
# 20200302 2
# 20200302 3
# 20200302 4
# 20200302 5
# 20200303 0
# 20200303 1
# 20200303 2
# 20200303 3
# 20200303 4
# 20200303 5
# 20200304 0
# 20200304 1
# 20200304 2
# 20200304 3
# 20200304 4
# 20200304 5
# 20200305 0
# 20200305 1
# 20200305 2
# 20200305 3
# 20200305 4
# 20200305 5
# 20200306 0
# 20200306 1
# 20200306 2
# 20200306 3
# 20200306 4
# 20200306 5
# 20200307 0
# 20200307 1
# 20200307 2
# 20200307 3
# 20200307 4
# 20200307 5
# 20200308 0
# 20200308 1
# 20200308 2
# 20200308 3
# 20200308 4
# 20200308 5
# 20200309 0
# 20200309 1
# 20200309 2
# 20200309 3
# 20200309 4
# 20200309 5
# 20200310 0
# 20200310 1
# 20200310 2
# 20200310 3
# 20200310 4
# 20200310 5
# 20200311 0
# 20200311 1
# 20200311 2
# 20200311 3
# 20200311 4
# 20200311 5
# 20200312 0
# 20200312 1
# 20200312 2
# 20200312 3
# 20200312 4
# 20200312 5
# 20200313 0
# 20200313 1
# 20200313 2
# 20200313 3
# 20200313 4
# 20200313 5
# 20200314 0
# 20200314 1
# 20200314 2
# 20200314 3
# 20200314 4
# 20200314 5
# 20200315 0
# 20200315 1
# 20200315 2
# 20200315 3
# 20200315 4
# 20200315 5
# 20200316 0
# 20200316 1
# 20200316 2
# 20200316 3
# 20200316 4
# 20200316 5
# 20200317 0
# 20200317 1
# 20200317 2
# 20200317 3
# 20200317 4
# 20200317 5
# 20200318 0
# 20200318 1
# 20200318 2
# 20200318 3
# 20200318 4
# 20200318 5
# 20200319 0
# 20200319 1
# 20200319 2
# 20200319 3
# 20200319 4
# 20200319 5
# 20200320 0
# 20200320 1
# 20200320 2
# 20200320 3
# 20200320 4
# 20200320 5
# 20200321 0
# 20200321 1
# 20200321 2
# 20200321 3
# 20200321 4
# 20200321 5
# 20200322 0
# 20200322 1
# 20200322 2
# 20200322 3
# 20200322 4
# 20200322 5
# 20200323 0
# 20200323 1
# 20200323 2
# 20200323 3
# 20200323 4
# 20200323 5
# 20200324 0
# 20200324 1
# 20200324 2
# 20200324 3
# 20200324 4
# 20200324 5
# 20200325 0
# 20200325 1
# 20200325 2
# 20200325 3
# 20200325 4
# 20200325 5
# 20200326 0
# 20200326 1
# 20200326 2
# 20200326 3
# 20200326 4
# 20200326 5
# 20200327 0
# 20200327 1
# 20200327 2
# 20200327 3
# 20200327 4
# 20200327 5
# 20200328 0
# 20200328 1
# 20200328 2
# 20200328 3
# 20200328 4
# 20200328 5
# 20200329 0
# 20200329 1
# 20200329 2
# 20200329 3
# 20200329 4
# 20200329 5
# 20200330 0
# 20200330 1
# 20200330 2
# 20200330 3
# 20200330 4
# 20200330 5
# 20200331 0
# 20200331 1
# 20200331 2
# 20200331 3
# 20200331 4
# 20200331 5
# 20200401 0
# 20200401 1
# 20200401 2
# 20200401 3
# 20200401 4
# 20200401 5
# 20200402 0
# 20200402 1
# 20200402 2
# 20200402 3
# 20200402 4
# 20200402 5
# 20200403 0
# 20200403 1
# 20200403 2
# 20200403 3
# 20200403 4
# 20200403 5
# 20200404 0
# 20200404 1
# 20200404 2
# 20200404 3
# 20200404 4
# 20200404 5
# 20200405 0
# 20200405 1
# 20200405 2
# 20200405 3
# 20200405 4
# 20200405 5
# 20200406 0
# 20200406 1
# 20200406 2
# 20200406 3
# 20200406 4
# 20200406 5
# 20200407 0
# 20200407 1
# 20200407 2
# 20200407 3
# 20200407 4
# 20200407 5
# 20200408 0
# 20200408 1
# 20200408 2
# 20200408 3
# 20200408 4
# 20200408 5
# 20200409 0
# 20200409 1
# 20200409 2
# 20200409 3
# 20200409 4
# 20200409 5
# 20200410 0
# 20200410 1
# 20200410 2
# 20200410 3
# 20200410 4
# 20200410 5
# 20200411 0
# 20200411 1
# 20200411 2
# 20200411 3
# 20200411 4
# 20200411 5
# 20200412 0
# 20200412 1
# 20200412 2
# 20200412 3
# 20200412 4
# 20200412 5
# 20200413 0
# 20200413 1
# 20200413 2
# 20200413 3
# 20200413 4
# 20200413 5
# 20200414 0
# 20200414 1
# 20200414 2
# 20200414 3
# 20200414 4
# 20200414 5
# 20200415 0
# 20200415 1
# 20200415 2
# 20200415 3
# 20200415 4
# 20200415 5
# 20200416 0
# 20200416 1
# 20200416 2
# 20200416 3
# 20200416 4
# 20200416 5
# 20200417 0
# 20200417 1
# 20200417 2
# 20200417 3
# 20200417 4
# 20200417 5
# 20200418 0
# 20200418 1
# 20200418 2
# 20200418 3
# 20200418 4
# 20200418 5
# 20200419 0
# 20200419 1
# 20200419 2
# 20200419 3
# 20200419 4
# 20200419 5
# 20200420 0
# 20200420 1
# 20200420 2
# 20200420 3
# 20200420 4
# 20200420 5
# 20200421 0
# 20200421 1
# 20200421 2
# 20200421 3
# 20200421 4
# 20200421 5
# 20200422 0
# 20200422 1
# 20200422 2
# 20200422 3
# 20200422 4
# 20200422 5
# 20200423 0
# 20200423 1
# 20200423 2
# 20200423 3
# 20200423 4
# 20200423 5
# 20200424 0
# 20200424 1
# 20200424 2
# 20200424 3
# 20200424 4
# 20200424 5
# 20200425 0
# 20200425 1
# 20200425 2
# 20200425 3
# 20200425 4
# 20200425 5
# 20200426 0
# 20200426 1
# 20200426 2
# 20200426 3
# 20200426 4
# 20200426 5
# 20200427 0
# 20200427 1
# 20200427 2
# 20200427 3
# 20200427 4
# 20200427 5
# 20200428 0
# 20200428 1
# 20200428 2
# 20200428 3
# 20200428 4
# 20200428 5
# 20200429 0
# 20200429 1
# 20200429 2
# 20200429 3
# 20200429 4
# 20200429 5
# 20200430 0
# 20200430 1
# 20200430 2
# 20200430 3
# 20200430 4
# 20200430 5
# 20200501 0
# 20200501 1
# 20200501 2
# 20200501 3
# 20200501 4
# 20200501 5
# 20200502 0
# 20200502 1
# 20200502 2
# 20200502 3
# 20200502 4
# 20200502 5
# 20200503 0
# 20200503 1
# 20200503 2
# 20200503 3
# 20200503 4
# 20200503 5
# 20200504 0
# 20200504 1
# 20200504 2
# 20200504 3
# 20200504 4
# 20200504 5
# 20200505 0
# 20200505 1
# 20200505 2
# 20200505 3
# 20200505 4
# 20200505 5
# 20200506 0
# 20200506 1
# 20200506 2
# 20200506 3
# 20200506 4
# 20200506 5
# 20200507 0
# 20200507 1
# 20200507 2
# 20200507 3
# 20200507 4
# 20200507 5
# 20200508 0
# 20200508 1
# 20200508 2
# 20200508 3
# 20200508 4
# 20200508 5
# 20200509 0
# 20200509 1
# 20200509 2
# 20200509 3
# 20200509 4
# 20200509 5
# 20200510 0
# 20200510 1
# 20200510 2
# 20200510 3
# 20200510 4
# 20200510 5
# 20200511 0
# 20200511 1
# 20200511 2
# 20200511 3
# 20200511 4
# 20200511 5
# 20200512 0
# 20200512 1
# 20200512 2
# 20200512 3
# 20200512 4
# 20200512 5
# 20200513 0
# 20200513 1
# 20200513 2
# 20200513 3
# 20200513 4
# 20200513 5
# 20200514 0
# 20200514 1
# 20200514 2
# 20200514 3
# 20200514 4
# 20200514 5
# 20200515 0
# 20200515 1
# 20200515 2
# 20200515 3
# 20200515 4
# 20200515 5
# 20200516 0
# 20200516 1
# 20200516 2
# 20200516 3
# 20200516 4
# 20200516 5
# 20200517 0
# 20200517 1
# 20200517 2
# 20200517 3
# 20200517 4
# 20200517 5
# 20200518 0
# 20200518 1
# 20200518 2
# 20200518 3
# 20200518 4
# 20200518 5
# 20200519 0
# 20200519 1
# 20200519 2
# 20200519 3
# 20200519 4
# 20200519 5
# 20200520 0
# 20200520 1
# 20200520 2
# 20200520 3
# 20200520 4
# 20200520 5
# 20200521 0
# 20200521 1
# 20200521 2
# 20200521 3
# 20200521 4
# 20200521 5
# 20200522 0
# 20200522 1
# 20200522 2
# 20200522 3
# 20200522 4
# 20200522 5
# 20200523 0
# 20200523 1
# 20200523 2
# 20200523 3
# 20200523 4
# 20200523 5
# 20200524 0
# 20200524 1
# 20200524 2
# 20200524 3
# 20200524 4
# 20200524 5
# 20200525 0
# 20200525 1
# 20200525 2
# 20200525 3
# 20200525 4
# 20200525 5
# 20200526 0
# 20200526 1
# 20200526 2
# 20200526 3
# 20200526 4
# 20200526 5
# 20200527 0
# 20200527 1
# 20200527 2
# 20200527 3
# 20200527 4
# 20200527 5
# 20200528 0
# 20200528 1
# 20200528 2
# 20200528 3
# 20200528 4
# 20200528 5
# 20200529 0
# 20200529 1
# 20200529 2
# 20200529 3
# 20200529 4
# 20200529 5
# 20200530 0
# 20200530 1
# 20200530 2
# 20200530 3
# 20200530 4
# 20200530 5
# 20200531 0
# 20200531 1
# 20200531 2
# 20200531 3
# 20200531 4
# 20200531 5
# 20200601 0
# 20200601 1
# 20200601 2
# 20200601 3
# 20200601 4
# 20200601 5
# 20200602 0
# 20200602 1
# 20200602 2
# 20200602 3
# 20200602 4
# 20200602 5
# 20200603 0
# 20200603 1
# 20200603 2
# 20200603 3
# 20200603 4
# 20200603 5
# 20200604 0
# 20200604 1
# 20200604 2
# 20200604 3
# 20200604 4
# 20200604 5
# 20200605 0
# 20200605 1
# 20200605 2
# 20200605 3
# 20200605 4
# 20200605 5
# 20200606 0
# 20200606 1
# 20200606 2
# 20200606 3
# 20200606 4
# 20200606 5
# 20200607 0
# 20200607 1
# 20200607 2
# 20200607 3
# 20200607 4
# 20200607 5
# 20200608 0
# 20200608 1
# 20200608 2
# 20200608 3
# 20200608 4
# 20200608 5
# 20200609 0
# 20200609 1
# 20200609 2
# 20200609 3
# 20200609 4
# 20200609 5
# 20200610 0
# 20200610 1
# 20200610 2
# 20200610 3
# 20200610 4
# 20200610 5
# 20200611 0
# 20200611 1
# 20200611 2
# 20200611 3
# 20200611 4
# 20200611 5
# 20200612 0
# 20200612 1
# 20200612 2
# 20200612 3
# 20200612 4
# 20200612 5
# 20200613 0
# 20200613 1
# 20200613 2
# 20200613 3
# 20200613 4
# 20200613 5
# 20200614 0
# 20200614 1
# 20200614 2
# 20200614 3
# 20200614 4
# 20200614 5
# 20200615 0
# 20200615 1
# 20200615 2
# 20200615 3
# 20200615 4
# 20200615 5
# 20200616 0
# 20200616 1
# 20200616 2
# 20200616 3
# 20200616 4
# 20200616 5
# 20200617 0
# 20200617 1
# 20200617 2
# 20200617 3
# 20200617 4
# 20200617 5
# 20200618 0
# 20200618 1
# 20200618 2
# 20200618 3
# 20200618 4
# 20200618 5
# 20200619 0
# 20200619 1
# 20200619 2
# 20200619 3
# 20200619 4
# 20200619 5
# 20200620 0
# 20200620 1
# 20200620 2
# 20200620 3
# 20200620 4
# 20200620 5
# 20200621 0
# 20200621 1
# 20200621 2
# 20200621 3
# 20200621 4
# 20200621 5
# 20200622 0
# 20200622 1
# 20200622 2
# 20200622 3
# 20200622 4
# 20200622 5
# 20200623 0
# 20200623 1
# 20200623 2
# 20200623 3
# 20200623 4
# 20200623 5
# 20200624 0
# 20200624 1
# 20200624 2
# 20200624 3
# 20200624 4
# 20200624 5
# 20200625 0
# 20200625 1
# 20200625 2
# 20200625 3
# 20200625 4
# 20200625 5
# 20200626 0
# 20200626 1
# 20200626 2
# 20200626 3
# 20200626 4
# 20200626 5
# 20200627 0
# 20200627 1
# 20200627 2
# 20200627 3
# 20200627 4
# 20200627 5
# 20200628 0
# 20200628 1
# 20200628 2
# 20200628 3
# 20200628 4
# 20200628 5
# 20200629 0
# 20200629 1
# 20200629 2
# 20200629 3
# 20200629 4
# 20200629 5
# 20200630 0
# 20200630 1
# 20200630 2
# 20200630 3
# 20200630 4
# 20200630 5
# 20200701 0
# 20200701 1
# 20200701 2
# 20200701 3
# 20200701 4
# 20200701 5
# 20200702 0
# 3 https://tts.news.naver.com/article/214/0001048871/summary
# 2 https://tts.news.naver.com/article/214/0001048871/summary
# 1 https://tts.news.naver.com/article/214/0001048871/summary
# [504] https://tts.news.naver.com/article/214/0001048871/summary
# 504
# Gateway Timeout
# {'date': 'Mon, 03 Aug 2020 05:36:23 GMT', 'cache-control': 'no-cache, no-store, must-revalidate', 'vary': 'Origin,Access-Control-Request-Method,Access-Control-Request-Headers', 'content-type': 'application/json', 'content-length': '212', 'referrer-policy': 'unsafe-url', 'server': 'nfront'}
# 20200702 1
# 20200702 2
# 20200702 3
# 20200702 4
# 20200702 5
# 20200703 0
# 20200703 1
# 20200703 2
# 20200703 3
# 20200703 4
# 20200703 5
# 20200704 0
# 20200704 1
# 20200704 2
# 20200704 3
# 20200704 4
# 20200704 5
# 20200705 0
# 20200705 1
# 20200705 2
# 20200705 3
# 20200705 4
# 20200705 5
# 20200706 0
# 20200706 1
# 20200706 2
# 20200706 3
# 20200706 4
# 20200706 5
# 20200707 0
# 20200707 1
# 20200707 2
# 20200707 3
# 20200707 4
# 20200707 5
# 20200708 0
# 20200708 1
# 20200708 2
# 20200708 3
# 20200708 4
# 20200708 5
# 20200709 0
# 20200709 1
# 20200709 2
# 20200709 3
# 20200709 4
# 20200709 5
# 20200710 0
# 20200710 1
# 20200710 2
# 20200710 3
# 20200710 4
# 20200710 5
# 20200711 0
# 20200711 1
# 20200711 2
# 20200711 3
# 20200711 4
# 20200711 5
# 20200712 0
# 20200712 1
# 20200712 2
# 20200712 3
# 20200712 4
# 20200712 5
# 20200713 0
# 20200713 1
# 20200713 2
# 20200713 3
# 20200713 4
# 20200713 5
# 20200714 0
# 20200714 1
# 20200714 2
# 20200714 3
# 20200714 4
# 20200714 5
# 20200715 0
# 20200715 1
# 20200715 2
# 20200715 3
# 20200715 4
# 20200715 5
# 20200716 0
# 20200716 1
# 20200716 2
# 20200716 3
# 20200716 4
# 20200716 5
# 20200717 0
# 20200717 1
# 20200717 2
# 20200717 3
# 20200717 4
# 20200717 5
# 20200718 0
# 20200718 1
# 20200718 2
# 20200718 3
# 20200718 4
# 20200718 5
# 20200719 0
# 20200719 1
# 20200719 2
# 20200719 3
# 20200719 4
# 20200719 5
# 20200720 0
# 20200720 1
# 20200720 2
# 20200720 3
# 20200720 4
# 20200720 5
# 20200721 0
# 20200721 1
# 20200721 2
# 20200721 3
# 20200721 4
# 20200721 5
# 20200722 0
# 20200722 1
# 20200722 2
# 20200722 3
# 20200722 4
# 20200722 5
# 20200723 0
# 20200723 1
# 20200723 2
# 20200723 3
# 20200723 4
# 20200723 5
# 20200724 0
# 20200724 1
# 20200724 2
# 20200724 3
# 20200724 4
# 20200724 5
# 20200725 0
# 20200725 1
# 20200725 2
# 20200725 3
# 20200725 4
# 20200725 5
# 20200726 0
# 20200726 1
# 20200726 2
# 20200726 3
# 20200726 4
# 20200726 5
# 20200727 0
# 20200727 1
# 20200727 2
# 20200727 3
# 20200727 4
# 20200727 5
# 20200728 0
# 20200728 1
# 20200728 2
# 20200728 3
# 20200728 4
# 20200728 5
# 20200729 0
# 20200729 1
# 20200729 2
# 20200729 3
# 20200729 4
# 20200729 5
# 3 https://tts.news.naver.com/article/138/0002089346/summary
# 2 https://tts.news.naver.com/article/138/0002089346/summary
# 1 https://tts.news.naver.com/article/138/0002089346/summary
# [500] https://tts.news.naver.com/article/138/0002089346/summary
# 500
# Internal Server Error
# {'date': 'Mon, 03 Aug 2020 06:05:14 GMT', 'cache-control': 'no-cache, no-store, must-revalidate', 'vary': 'Origin,Access-Control-Request-Method,Access-Control-Request-Headers', 'access-control-allow-credentials': 'true', 'content-type': 'application/json;charset=UTF-8', 'transfer-encoding': 'chunked', 'referrer-policy': 'unsafe-url', 'server': 'nfront'}
# 20200730 0
# 20200730 1
# 20200730 2
# 20200730 3
# 20200730 4
# 20200730 5
# 20200731 0
# 20200731 1
# 20200731 2
# 20200731 3
# 20200731 4
# 20200731 5
# 20200801 0
# 20200801 1
# 20200801 2
# 20200801 3
# 20200801 4
# 20200801 5
# 20200802 0
# 20200802 1
# 20200802 2
# 20200802 3
# 20200802 4
# 20200802 5

# %%
cur.close()
conn.close()
